# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from datasets import load_dataset

# %%
dataset = load_dataset("windchimeran/GMRID")
# Out:
# README.md:   0%|          | 0.00/4.30k [00:00<?, ?B/s]
# c:\Users\prakh\OneDrive\Documents\INTERNSHIP WORK\gmrid-risk-classification-project\gmrid_env\Lib\site-packages\huggingface_hub\file_download.py:142: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\prakh\.cache\huggingface\hub\datasets--windchimeran--GMRID. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# GMRID_v3-train.csv:   0%|          | 0.00/8.22M [00:00<?, ?B/s]
# GMRID_v3-test.csv:   0%|          | 0.00/2.30M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/4594 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1147 [00:00<?, ? examples/s]

# %%
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'Headline', 'Details', 'Severity', 'Region', 'Datetime', 'lat', 'lon', 'maritime_label', 'found_ports', 'contains_port_info', 'if_labeled', 'Headline_Details', 'Year', 'Month', 'Week', 'Details_cleaned', 'Category', 'Summarized_label', 'gpt-4o_label'],
#         num_rows: 4594
#     })
#     test: Dataset({
#         features: ['id', 'Headline', 'Details', 'Severity', 'Region', 'Datetime', 'lat', 'lon', 'maritime_label', 'found_ports', 'contains_port_info', 'if_labeled', 'Headline_Details', 'Year', 'Month', 'Week', 'Details_cleaned', 'Category', 'Summarized_label', 'gpt-4o_label'],
#         num_rows: 1147
#     })
# })

# %%
print(dataset.keys())
# Out:
# dict_keys(['train', 'test'])

# %%
train_df = dataset["train"].to_pandas()
test_df = dataset["test"].to_pandas()

# %%
print(train_df.shape)
print(test_df.shape)
print(train_df.columns.tolist())
# Out:
# (4594, 20)
# (1147, 20)
# ['id', 'Headline', 'Details', 'Severity', 'Region', 'Datetime', 'lat', 'lon', 'maritime_label', 'found_ports', 'contains_port_info', 'if_labeled', 'Headline_Details', 'Year', 'Month', 'Week', 'Details_cleaned', 'Category', 'Summarized_label', 'gpt-4o_label']

# %%
train_df.head()
# Out:
#      id                                           Headline  \
# 0   552  Severe winds caused brief suspension at Port o...
# 1   933  USA, California: Emergency personnel working t...
# 2  2973  USA: 'Fridays for Future' climate change prote...
# 3     6  UPDATE - Indonesia: Severe winds damage infras...
# 4  4537  UPDATE 1 - Refrigerated container import capac...
#
#                                              Details  Severity         Region  \
# 0  Local sources reported that operations at Pier...     Minor   South Africa
# 1  Information received states that emergency per...  Moderate  United States
# 2  Protests against climate change are anticipate...     Minor  United States
# 3  Severe winds have downed billboards and trees ...  Moderate      Indonesia
# 4  Updated sources indicate that terminals at the...  Moderate          China
#
#               Datetime        lat       lon maritime_label   found_ports  \
# 0  2018-12-28 05:15:00  -29.88386  31.01766           true    ['durban']
# 1  2018-11-17 06:25:00     32.821  -117.153          false    ['balboa']
# 2  2019-11-27 07:00:00        NaN       NaN          false  ['new york']
# 3  2017-04-19 09:10:00   -6.91264   107.657          false   ['jakarta']
# 4  2020-02-03 21:57:00   38.98074   117.746           true   ['tianjin']
#
#   contains_port_info if_labeled  \
# 0               true       true
# 1               true      false
# 2               true      false
# 3               true       true
# 4               true       true
#
#                                     Headline_Details  Year  Month  Week  \
# 0  Severe winds caused brief suspension at Port o...  2018     12    52
# 1  USA, California: Emergency personnel working t...  2018     11    46
# 2  USA: 'Fridays for Future' climate change prote...  2019     11    48
# 3  UPDATE - Indonesia: Severe winds damage infras...  2017      4    16
# 4  UPDATE 1 - Refrigerated container import capac...  2020      2     6
#
#                                      Details_cleaned  \
# 0  local source reported operation pier 1 2 conta...
# 1  information received state emergency personnel...
# 2  protest climate change anticipated nationwide ...
# 3  severe wind downed billboard tree bandung wedn...
# 4  updated source indicate terminal tianjin port ...
#
#                                             Category      Summarized_label  \
# 0                                    Port Disruption               Weather
# 1  Roadway Closure / Disruption, Non-industrial Fire  Administrative Issue
# 2                                     Protest / Riot         Worker Strike
# 3  Roadway Closure / Disruption, Flooding, Severe...               Weather
# 4  Port Disruption, Cargo Disruption, Port Conges...  Administrative Issue
#
#   gpt-4o_label
# 0           {}
# 1           {}
# 2           {}
# 3           {}
# 4           {}

# %%
train_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4594 entries, 0 to 4593
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  4594 non-null   int64
#  1   Headline            4594 non-null   str
#  2   Details             4594 non-null   str
#  3   Severity            4594 non-null   str
#  4   Region              4594 non-null   str
#  5   Datetime            4594 non-null   str
#  6   lat                 3097 non-null   str
#  7   lon                 3097 non-null   str
#  8   maritime_label      4594 non-null   str
#  9   found_ports         4594 non-null   str
#  10  contains_port_info  4594 non-null   str
#  11  if_labeled          4593 non-null   str
#  12  Headline_Details    4593 non-null   str
#  13  Year                4594 non-null   int64
#  14  Month               4594 non-null   int64
#  15  Week                4594 non-null   int64
#  16  Details_cleaned     4594 non-null   str
#  17  Category            4594 non-null   str
#  18  Summarized_label    4594 non-null   str
#  19  gpt-4o_label        4594 non-null   str
# dtypes: int64(4), str(16)
# memory usage: 8.4 MB

# %%
for col in train_df.columns:
    print(col, train_df[col].nunique())
# Out:
# id 4594
# Headline 4529
# Details 4594
# Severity 4
# Region 109
# Datetime 4559
# lat 2737
# lon 2725
# maritime_label 2
# found_ports 507
# contains_port_info 1
# if_labeled 2
# Headline_Details 4593
# Year 4
# Month 12
# Week 53
# Details_cleaned 4594
# Category 723
# Summarized_label 8
# gpt-4o_label 1

# %% [markdown]
# category columns are severity , maritime_label , contain_port_info , if_labelled , summarized label and gpt-4o_label
